# %%
#get input
s = speed_limit = int(input())
d = driving_speed = int(input())

#Initialize the traffic ticket amount to 0
t = traffic_ticket_amount = 0
#Condition statement to compare the speed limit to the driving speed and determine the ticket amount
if d<= s-10:
  t = 50
elif d>= s+6 and d<=s+20:
  t=75
elif d>= s+21 and d<=s+40:
  t = 150
elif d>= s+41:
  t = 300

#output the traffic ticket amount
print(t)
# Out:
# 35
# 26
# 0
